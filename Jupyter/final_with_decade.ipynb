# %%
import pandas as pd
import numpy as np

# %%
spotify_db = pd.read_csv('final_with_decade.csv')
spotify_db
# Out:
#      Unnamed: 0                                   URI  \
# 0           0.0  spotify:track:1fhLgOJgIIZEsWWffk8ljs
# 1           1.0  spotify:track:5dae01pKNjRQtgOeAkFzPY
# 2           2.0  spotify:track:68GJRIs9vkHFy9l0Sbdsix
# 3           3.0  spotify:track:33FdwvfiSBRbE2AQ4UehaR
# 4           4.0  spotify:track:68ZOKozM9xmlp1iwaQSwY7
# 5           5.0  spotify:track:5uEwpyOYHFGqme4WnVQhfs
# 6           6.0  spotify:track:7Jf323ttHKUnPylFWiaGl3
# 7           7.0  spotify:track:00vJeips2Rwr2qN1qODvyf
# 8           8.0  spotify:track:3RxI4EHxmNqd7nHJPqbxUm
# 9           9.0  spotify:track:0zII0Soax7wbm3Avw7iVAd
# 10         10.0  spotify:track:1hVEHu6SemMvlYAP5MWkDj
# 11         11.0  spotify:track:3GVyT9fBXuEkGs1STo2WHZ
# 12         12.0  spotify:track:7bETs6oajlWYVo9ycX74Vp
# 13         13.0  spotify:track:3Rd7lzhb3AtQPuQ4UZiSCc
# 14         14.0  spotify:track:1nz7qrpaifFdBUp22qde4O
# 15         15.0  spotify:track:0VLsWxGXctGx9QtaHCpVEk
# ...

# %%
# df.drop(['Unnamed: 0'])
spotify_db['Release Date']=spotify_db['Release Date']
spotify_db['Release Date Decade']=spotify_db['Release Date Decade']

# %%
spotify_db.head()
# Out:
#    Unnamed: 0                                   URI           Artist  \
# 0         0.0  spotify:track:1fhLgOJgIIZEsWWffk8ljs      The Weavers
# 1         1.0  spotify:track:5dae01pKNjRQtgOeAkFzPY    Nat King Cole
# 2         2.0  spotify:track:68GJRIs9vkHFy9l0Sbdsix  Various Artists
# 3         3.0  spotify:track:33FdwvfiSBRbE2AQ4UehaR      Bing Crosby
# 4         4.0  spotify:track:68ZOKozM9xmlp1iwaQSwY7    Teresa Brewer
#
#                                     Song Release Date  Release Date Decade  \
# 0                        Goodnight Irene       1950.0               1950.0
# 1                              Mona Lisa       1950.0               1950.0
# 2   The Third Man (The Harry Lime Theme)       1950.0               1950.0
# 3  Play A Simple Melody - Single Version       1950.0               1950.0
# 4                   Music! Music! Music!       1950.0               1950.0
#
#    Popularity  Acousticness  Danceability  Energy  Instrumentalness  Loudness  \
# ...

# %%
import sqlite3

conn = sqlite3.connect('spotify_db.sqlite')
spotify_db.to_sql('spotify_db', conn, if_exists='replace', index=False)
pd.read_sql('select * from spotify_db', conn)
# Out:
# C:\Users\kalbrecht\Anaconda\anaconda3\lib\site-packages\pandas\core\generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)
#      Unnamed: 0                                   URI  \
# 0           0.0  spotify:track:1fhLgOJgIIZEsWWffk8ljs
# 1           1.0  spotify:track:5dae01pKNjRQtgOeAkFzPY
# 2           2.0  spotify:track:68GJRIs9vkHFy9l0Sbdsix
# 3           3.0  spotify:track:33FdwvfiSBRbE2AQ4UehaR
# 4           4.0  spotify:track:68ZOKozM9xmlp1iwaQSwY7
# 5           5.0  spotify:track:5uEwpyOYHFGqme4WnVQhfs
# 6           6.0  spotify:track:7Jf323ttHKUnPylFWiaGl3
# 7           7.0  spotify:track:00vJeips2Rwr2qN1qODvyf
# 8           8.0  spotify:track:3RxI4EHxmNqd7nHJPqbxUm
# 9           9.0  spotify:track:0zII0Soax7wbm3Avw7iVAd
# 10         10.0  spotify:track:1hVEHu6SemMvlYAP5MWkDj
# 11         11.0  spotify:track:3GVyT9fBXuEkGs1STo2WHZ
# ...
