# %%
import spotipy
import pandas as pd
import pprint as pprint
from config import client_id
from config import client_secret
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id,
                                                     client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
billboard = pd.read_csv('final.csv')
billboard_df = pd.DataFrame(billboard)
billboard_df.head()
# Out:
#                                     URI           Artist  \
# 0  spotify:track:1fhLgOJgIIZEsWWffk8ljs      The Weavers
# 1  spotify:track:5dae01pKNjRQtgOeAkFzPY    Nat King Cole
# 2  spotify:track:68GJRIs9vkHFy9l0Sbdsix  Various Artists
# 3  spotify:track:33FdwvfiSBRbE2AQ4UehaR      Bing Crosby
# 4  spotify:track:68ZOKozM9xmlp1iwaQSwY7    Teresa Brewer
#
#                                     Song  Release Date  Popularity  \
# 0                        Goodnight Irene          1950          13
# 1                              Mona Lisa          1950          51
# 2   The Third Man (The Harry Lime Theme)          1950          12
# 3  Play A Simple Melody - Single Version          1950          10
# 4                   Music! Music! Music!          1950          26
#
#    Acousticness  Danceability  Energy  Instrumentalness  Loudness  \
# 0         0.832         0.367   0.261          0.000000   -10.404
# 1         0.948         0.251   0.225          0.000000   -12.125
# ...

# %%
images=[]

for i in billboard_df["URI"]:
    images.append(sp.track(i)["album"]["images"][1]["url"])

# %%
images.append(sp.track("1fhLgOJgIIZEsWWffk8ljs")["album"]["images"][1]["url"][0])

# %%
images
# Out:
# ['https://i.scdn.co/image/732355c0876f9627b27590ac28506e69908e9039',
#  'https://i.scdn.co/image/c965a1de893cf294af0ed77c578dd36f20ce1928',
#  'https://i.scdn.co/image/ab67616d00001e02b7410c244d8f8502f63c821b',
#  'https://i.scdn.co/image/83435befe3622ffcfc0b32738a2a1653564074be',
#  'https://i.scdn.co/image/84358ff1d09685a1f21cad7b09fc5f35cf923eb9',
#  'https://i.scdn.co/image/ab67616d00001e02a8b83928cf036995c6efab57',
#  'https://i.scdn.co/image/94c6270de2c012cfcf51e57a065f189772d373d4',
#  'https://i.scdn.co/image/ab67616d00001e0285e3b1a8039abef513d43f9c',
#  'https://i.scdn.co/image/ab67616d00001e025b2ccbbb29f989aded75dde0',
#  'https://i.scdn.co/image/65ba5bb47d7fac4ae7233a120773304035709131',
#  'https://i.scdn.co/image/ab67616d00001e02c2c103caf406c34746736307',
#  'https://i.scdn.co/image/ab67616d00001e02a1bd4e463daa74b780125e9a',
#  'https://i.scdn.co/image/ab67616d00001e02668be5ce0a0d494c19060fef',
#  'https://i.scdn.co/image/732355c0876f9627b27590ac28506e69908e9039',
# ...

# %%
len(images)
# Out:
# 547
