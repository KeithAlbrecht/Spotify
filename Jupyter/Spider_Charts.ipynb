# %%
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from math import pi

# %%
gbd_df = pd.read_csv('C:/Users/kalbrecht/Desktop/Final Project/gbd.csv', encoding="windows-1252")
gbd_df

df = gbd_df

final_scaled = pd.read_csv('C:/Users/kalbrecht/Desktop/Final Project/final_scaled.csv', encoding="windows-1252")
final_scaled_df = final_scaled.set_index("URI", drop = False)

# %%
the_50s = df.iloc[0].values
the_60s = df.iloc[1].values
the_70s = df.iloc[2].values
the_80s = df.iloc[3].values
the_90s = df.iloc[4].values
the_2000s = df.iloc[5].values
the_2010s = df.iloc[6].values

# %%
# number of variable
categories= ["Popularity","Acousticness","Danceability","Energy","Instrumentalness","Loudness",
                   "Speechiness","Tempo","Valence","Duration"]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels 
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)

plt.yticks([.25,0.5,.75,1.0,1.25,1.5,1.75,2.0,2.25], ["0.25","0.5","0.75","1.0","1.25","1.5","1.75","2.0","2.25"], color="grey", size=12)
plt.ylim(0,2.25)


# ------- PART 2: Add plots (do this in the same programming cell!)
 
# Plot each individual = each line of the data
dropdown = the_50s#, the_60s, the_70s, the_80s, the_90s, the_2000s, the_2010s
decade = "1950s"#,"1960s","1970s","1980s","1990s","2000s","2010s"    
    
    
# Decade Chart Data
values=dropdown.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=decade)
ax.fill(angles, values, 'b', alpha=0.1)

# YOUR SONG

your_song=final_scaled_df.loc["spotify:track:1fhLgOJgIIZEsWWffk8ljs", : ].values
your_song_values = your_song[1:]

values=your_song_values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Your_Song")
ax.fill(angles, values, 'o', alpha=0.1)   

    
# Add legend
plt.legend(loc='best', bbox_to_anchor=(0.1, 0.1))
